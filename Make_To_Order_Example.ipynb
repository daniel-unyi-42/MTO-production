# %%
import pulp
import numpy as np

# %% [markdown]
# ## MAKE-TO-ORDER PRODUCTION

# %% [markdown]
# Dataset (can be read from a spreadsheet):

# %%
l = np.array([[8, 8],
              [8, 8],
              [8, 8]]) # length of each shift s on day t (hours)

b = np.array([[[8, 8],
               [8, 8],
               [8, 8]],
              [[8, 8],
               [8, 8],
               [8, 8]],
              [[8, 8],
               [8, 8],
               [8, 8]]]) # available capacity of resource r in shift s on day t (hours)

# each order j follows a processing route where the operations have a linear precedence relationship
p = np.array([[[0, 0, 14],
               [12, 0, 0],
               [0, 14, 0]],
              [[0, 0, 14],
               [10, 0, 0],
               [0, 14, 0]],
              [[8, 0, 0],
               [0, 0, 6],
               [0, 8, 0]]]) # processing time of operation o on order j with resource r (hours)

d = np.array([3, 3, 3]) # due date of order j (days)

q = np.array([10000, 9800, 6500]) # selling price of order j (USD)

c = np.array([[200, 300],
              [200, 250],
              [200, 200]]) # cost of using resource r in shift s on day t (USD/hour)

# %%
J = list(range(p.shape[0])) # orders
O = list(range(p.shape[1])) # operations
R = list(range(p.shape[2])) # resources
T = list(range(l.shape[0])) # days
S = list(range(l.shape[1])) # shifts

# %% [markdown]
# Variables:

# %%
# hours operation o of order j is processed on resource r in shift s on day t
X = np.array([[[[[pulp.LpVariable('X' + ''.join([str(index)
                  for index in (j, o, r, t, s)]), lowBound=0, cat="Continuous")
                  for s in S] for t in T] for r in R] for o in O] for j in J])

# 1 if operation o of order j is processed on resource r in shift s on day t
# 0 otherwise
Y = np.array([[[[[pulp.LpVariable('Y' + ''.join([str(index)
                  for index in (j, o, r, t, s)]), cat="Binary")
                  for s in S] for t in T] for r in R] for o in O] for j in J])

# 1 if order j is selected
# 0 otherwise
U = np.array([pulp.LpVariable(str(j), cat="Binary") for j in J])

# %% [markdown]
# Defining the problem:

# %%
problem = pulp.LpProblem("make-to-order production", pulp.LpMaximize)
# Out:
# /opt/conda/lib/python3.7/site-packages/pulp/pulp.py:1352: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")

# %% [markdown]
# First, we add the objective function to the problem:

# %%
problem += pulp.lpSum([q[j] * U[j] for j in J])\
         - pulp.lpSum([c[r, s] * X[j, o, r, t, s]
           for s in S for t in T for r in R for o in O for j in J])

# %% [markdown]
# Then we add all the constraints (we have already added the nonnegativity and integer constraints earlier, when we created the variables):

# %%
# whenever an operation is processed on a resource it should be processed \
# for at least "tau" hours (or other unit of time)
tau = 1 

constraints = []

constraints += [pulp.lpSum([X[j,o,r,t,s] for j in J for o in O]) <= b[r,t,s]
                for s in S for t in T for r in R] # (1)

constraints += [pulp.lpSum([X[j,o,r,t,s] for t in T for s in S]) >= p[j,o,r] * U[j]
                for r in R for o in O for j in J] # (2)

constraints += [pulp.lpSum([X[j,o,r,t,s] for o in O for r in R]) <= l[t,s]
                for s in S for t in T for j in J] # (3)

constraints += [X[j,o,r,t,s] >= tau*Y[j,o,r,t,s]
                for s in S for t in T for r in R for o in O for j in J] # (4)

constraints += [X[j,o,r,t,s] <= p[j,o,r] * Y[j,o,r,t,s]
                for s in S for t in T for r in R for o in O for j in J] # (5)

constraints += [pulp.lpSum([t*Y[j,len(O)-1,r,t,s] for r in R]) <= d[j] * U[j]
                for s in S for t in T for j in J] # (6)

constraints += [pulp.lpSum([X[j,o-1,r,t_,s_] for t_ in range(0, t-1) for s_ in S]) \
                + pulp.lpSum([X[j,o-1,r,t,s_] for s_ in range(0, s)]) >= \
                p[j,o-1,r] * pulp.lpSum([Y[j,o,r_,t,s] for r_ in R])
                for s in S[:-1] for t in T for r in R for o in O[1:] for j in J] # (7)
                
constraints += [pulp.lpSum([pulp.lpSum([X[j,o-1,r,t_,s] for t_ in range(0, t)]) for s in S]) >= \
                p[j,o-1,r] * pulp.lpSum([Y[j,o,r_,t,len(S)-1] for r_ in R])
                for t in T for r in R for o in O[1:] for j in J] # (8)

for constraint in constraints:
  problem += constraint

# %% [markdown]
# So the problem is the following:

# %%
print(problem)
# Out:
# make-to-order_production:
# MAXIMIZE
# 10000*0 + 9800*1 + 6500*2 + -200*X00000 + -300*X00001 + -200*X00010 + -300*X00011 + -200*X00020 + -300*X00021 + -200*X00100 + -250*X00101 + -200*X00110 + -250*X00111 + -200*X00120 + -250*X00121 + -200*X00200 + -200*X00201 + -200*X00210 + -200*X00211 + -200*X00220 + -200*X00221 + -200*X01000 + -300*X01001 + -200*X01010 + -300*X01011 + -200*X01020 + -300*X01021 + -200*X01100 + -250*X01101 + -200*X01110 + -250*X01111 + -200*X01120 + -250*X01121 + -200*X01200 + -200*X01201 + -200*X01210 + -200*X01211 + -200*X01220 + -200*X01221 + -200*X02000 + -300*X02001 + -200*X02010 + -300*X02011 + -200*X02020 + -300*X02021 + -200*X02100 + -250*X02101 + -200*X02110 + -250*X02111 + -200*X02120 + -250*X02121 + -200*X02200 + -200*X02201 + -200*X02210 + -200*X02211 + -200*X02220 + -200*X02221 + -200*X10000 + -300*X10001 + -200*X10010 + -300*X10011 + -200*X10020 + -300*X10021 + -200*X10100 + -250*X10101 + -200*X10110 + -250*X10111 + -200*X10120 + -250*X10121 + -200*X10200 + -200*X10201 + -200*X10210 + -200*X10211 + -200*X10220 + -200*X10221 + -200*X11000 + -300*X11001 + -200*X11010 + -300*X11011 + -200*X11020 + -300*X11021 + -200*X11100 + -250*X11101 + -200*X11110 + -250*X11111 + -200*X11120 + -250*X11121 + -200*X11200 + -200*X11201 + -200*X11210 + -200*X11211 + -200*X11220 + -200*X11221 + -200*X12000 + -300*X12001 + -200*X12010 + -300*X12011 + -200*X12020 + -300*X12021 + -200*X12100 + -250*X12101 + -200*X12110 + -250*X12111 + -200*X12120 + -250*X12121 + -200*X12200 + -200*X12201 + -200*X12210 + -200*X12211 + -200*X12220 + -200*X12221 + -200*X20000 + -300*X20001 + -200*X20010 + -300*X20011 + -200*X20020 + -300*X20021 + -200*X20100 + -250*X20101 + -200*X20110 + -250*X20111 + -200*X20120 + -250*X20121 + -200*X20200 + -200*X20201 + -200*X20210 + -200*X20211 + -200*X20220 + -200*X20221 + -200*X21000 + -300*X21001 + -200*X21010 + -300*X21011 + -200*X21020 + -300*X21021 + -200*X21100 + -250*X21101 + -200*X21110 + -250*X21111 + -200*X21120 + -250*X21121 + -200*X21200 + -200*X21201 + -200*X21210 + -200*X21211 + -200*X21220 + -200*X21221 + -200*X22000 + -300*X22001 + -200*X22010 + -300*X22011 + -200*X22020 + -300*X22021 + -200*X22100 + -250*X22101 + -200*X22110 + -250*X22111 + -200*X22120 + -250*X22121 + -200*X22200 + -200*X22201 + -200*X22210 + -200*X22211 + -200*X22220 + -200*X22221 + 0
# SUBJECT TO
# _C1: X00000 + X01000 + X02000 + X10000 + X11000 + X12000 + X20000 + X21000
#  + X22000 <= 8
#
# _C2: X00100 + X01100 + X02100 + X10100 + X11100 + X12100 + X20100 + X21100
#  + X22100 <= 8
#
# _C3: X00200 + X01200 + X02200 + X10200 + X11200 + X12200 + X20200 + X21200
#  + X22200 <= 8
#
# _C4: X00010 + X01010 + X02010 + X10010 + X11010 + X12010 + X20010 + X21010
#  + X22010 <= 8
#
# _C5: X00110 + X01110 + X02110 + X10110 + X11110 + X12110 + X20110 + X21110
#  + X22110 <= 8
#
# _C6: X00210 + X01210 + X02210 + X10210 + X11210 + X12210 + X20210 + X21210
#  + X22210 <= 8
#
# _C7: X00020 + X01020 + X02020 + X10020 + X11020 + X12020 + X20020 + X21020
#  + X22020 <= 8
#
# _C8: X00120 + X01120 + X02120 + X10120 + X11120 + X12120 + X20120 + X21120
#  + X22120 <= 8
#
# _C9: X00220 + X01220 + X02220 + X10220 + X11220 + X12220 + X20220 + X21220
#  + X22220 <= 8
#
# _C10: X00001 + X01001 + X02001 + X10001 + X11001 + X12001 + X20001 + X21001
#  + X22001 <= 8
#
# _C11: X00101 + X01101 + X02101 + X10101 + X11101 + X12101 + X20101 + X21101
#  + X22101 <= 8
#
# _C12: X00201 + X01201 + X02201 + X10201 + X11201 + X12201 + X20201 + X21201
#  + X22201 <= 8
#
# _C13: X00011 + X01011 + X02011 + X10011 + X11011 + X12011 + X20011 + X21011
#  + X22011 <= 8
#
# _C14: X00111 + X01111 + X02111 + X10111 + X11111 + X12111 + X20111 + X21111
#  + X22111 <= 8
#
# _C15: X00211 + X01211 + X02211 + X10211 + X11211 + X12211 + X20211 + X21211
#  + X22211 <= 8
#
# _C16: X00021 + X01021 + X02021 + X10021 + X11021 + X12021 + X20021 + X21021
#  + X22021 <= 8
#
# _C17: X00121 + X01121 + X02121 + X10121 + X11121 + X12121 + X20121 + X21121
#  + X22121 <= 8
#
# _C18: X00221 + X01221 + X02221 + X10221 + X11221 + X12221 + X20221 + X21221
#  + X22221 <= 8
#
# _C19: X00000 + X00001 + X00010 + X00011 + X00020 + X00021 >= 0
#
# _C20: X10000 + X10001 + X10010 + X10011 + X10020 + X10021 >= 0
#
# _C21: - 8 2 + X20000 + X20001 + X20010 + X20011 + X20020 + X20021 >= 0
#
# _C22: - 12 0 + X01000 + X01001 + X01010 + X01011 + X01020 + X01021 >= 0
#
# _C23: - 10 1 + X11000 + X11001 + X11010 + X11011 + X11020 + X11021 >= 0
#
# _C24: X21000 + X21001 + X21010 + X21011 + X21020 + X21021 >= 0
#
# _C25: X02000 + X02001 + X02010 + X02011 + X02020 + X02021 >= 0
#
# _C26: X12000 + X12001 + X12010 + X12011 + X12020 + X12021 >= 0
#
# _C27: X22000 + X22001 + X22010 + X22011 + X22020 + X22021 >= 0
#
# _C28: X00100 + X00101 + X00110 + X00111 + X00120 + X00121 >= 0
#
# _C29: X10100 + X10101 + X10110 + X10111 + X10120 + X10121 >= 0
#
# _C30: X20100 + X20101 + X20110 + X20111 + X20120 + X20121 >= 0
#
# _C31: X01100 + X01101 + X01110 + X01111 + X01120 + X01121 >= 0
#
# _C32: X11100 + X11101 + X11110 + X11111 + X11120 + X11121 >= 0
#
# _C33: X21100 + X21101 + X21110 + X21111 + X21120 + X21121 >= 0
#
# _C34: - 14 0 + X02100 + X02101 + X02110 + X02111 + X02120 + X02121 >= 0
#
# _C35: - 14 1 + X12100 + X12101 + X12110 + X12111 + X12120 + X12121 >= 0
#
# _C36: - 8 2 + X22100 + X22101 + X22110 + X22111 + X22120 + X22121 >= 0
#
# _C37: - 14 0 + X00200 + X00201 + X00210 + X00211 + X00220 + X00221 >= 0
#
# _C38: - 14 1 + X10200 + X10201 + X10210 + X10211 + X10220 + X10221 >= 0
#
# _C39: X20200 + X20201 + X20210 + X20211 + X20220 + X20221 >= 0
#
# _C40: X01200 + X01201 + X01210 + X01211 + X01220 + X01221 >= 0
#
# _C41: X11200 + X11201 + X11210 + X11211 + X11220 + X11221 >= 0
#
# _C42: - 6 2 + X21200 + X21201 + X21210 + X21211 + X21220 + X21221 >= 0
#
# _C43: X02200 + X02201 + X02210 + X02211 + X02220 + X02221 >= 0
#
# _C44: X12200 + X12201 + X12210 + X12211 + X12220 + X12221 >= 0
#
# _C45: X22200 + X22201 + X22210 + X22211 + X22220 + X22221 >= 0
#
# _C46: X00000 + X00100 + X00200 + X01000 + X01100 + X01200 + X02000 + X02100
#  + X02200 <= 8
#
# _C47: X10000 + X10100 + X10200 + X11000 + X11100 + X11200 + X12000 + X12100
#  + X12200 <= 8
#
# _C48: X20000 + X20100 + X20200 + X21000 + X21100 + X21200 + X22000 + X22100
#  + X22200 <= 8
#
# _C49: X00010 + X00110 + X00210 + X01010 + X01110 + X01210 + X02010 + X02110
#  + X02210 <= 8
#
# _C50: X10010 + X10110 + X10210 + X11010 + X11110 + X11210 + X12010 + X12110
#  + X12210 <= 8
#
# _C51: X20010 + X20110 + X20210 + X21010 + X21110 + X21210 + X22010 + X22110
#  + X22210 <= 8
#
# _C52: X00020 + X00120 + X00220 + X01020 + X01120 + X01220 + X02020 + X02120
#  + X02220 <= 8
#
# _C53: X10020 + X10120 + X10220 + X11020 + X11120 + X11220 + X12020 + X12120
#  + X12220 <= 8
#
# _C54: X20020 + X20120 + X20220 + X21020 + X21120 + X21220 + X22020 + X22120
#  + X22220 <= 8
#
# _C55: X00001 + X00101 + X00201 + X01001 + X01101 + X01201 + X02001 + X02101
#  + X02201 <= 8
#
# _C56: X10001 + X10101 + X10201 + X11001 + X11101 + X11201 + X12001 + X12101
#  + X12201 <= 8
#
# _C57: X20001 + X20101 + X20201 + X21001 + X21101 + X21201 + X22001 + X22101
#  + X22201 <= 8
#
# _C58: X00011 + X00111 + X00211 + X01011 + X01111 + X01211 + X02011 + X02111
#  + X02211 <= 8
#
# _C59: X10011 + X10111 + X10211 + X11011 + X11111 + X11211 + X12011 + X12111
#  + X12211 <= 8
#
# _C60: X20011 + X20111 + X20211 + X21011 + X21111 + X21211 + X22011 + X22111
#  + X22211 <= 8
#
# _C61: X00021 + X00121 + X00221 + X01021 + X01121 + X01221 + X02021 + X02121
#  + X02221 <= 8
#
# _C62: X10021 + X10121 + X10221 + X11021 + X11121 + X11221 + X12021 + X12121
#  + X12221 <= 8
#
# _C63: X20021 + X20121 + X20221 + X21021 + X21121 + X21221 + X22021 + X22121
#  + X22221 <= 8
#
# _C64: X00000 - Y00000 >= 0
#
# _C65: X10000 - Y10000 >= 0
#
# _C66: X20000 - Y20000 >= 0
#
# _C67: X01000 - Y01000 >= 0
#
# _C68: X11000 - Y11000 >= 0
#
# _C69: X21000 - Y21000 >= 0
#
# _C70: X02000 - Y02000 >= 0
#
# _C71: X12000 - Y12000 >= 0
#
# _C72: X22000 - Y22000 >= 0
#
# _C73: X00100 - Y00100 >= 0
#
# _C74: X10100 - Y10100 >= 0
#
# _C75: X20100 - Y20100 >= 0
#
# _C76: X01100 - Y01100 >= 0
#
# _C77: X11100 - Y11100 >= 0
#
# _C78: X21100 - Y21100 >= 0
#
# _C79: X02100 - Y02100 >= 0
#
# _C80: X12100 - Y12100 >= 0
#
# _C81: X22100 - Y22100 >= 0
#
# _C82: X00200 - Y00200 >= 0
#
# _C83: X10200 - Y10200 >= 0
#
# _C84: X20200 - Y20200 >= 0
#
# _C85: X01200 - Y01200 >= 0
#
# _C86: X11200 - Y11200 >= 0
#
# _C87: X21200 - Y21200 >= 0
#
# _C88: X02200 - Y02200 >= 0
#
# _C89: X12200 - Y12200 >= 0
#
# _C90: X22200 - Y22200 >= 0
#
# _C91: X00010 - Y00010 >= 0
#
# _C92: X10010 - Y10010 >= 0
#
# _C93: X20010 - Y20010 >= 0
#
# _C94: X01010 - Y01010 >= 0
#
# _C95: X11010 - Y11010 >= 0
#
# _C96: X21010 - Y21010 >= 0
#
# _C97: X02010 - Y02010 >= 0
#
# _C98: X12010 - Y12010 >= 0
#
# _C99: X22010 - Y22010 >= 0
#
# _C100: X00110 - Y00110 >= 0
#
# _C101: X10110 - Y10110 >= 0
#
# _C102: X20110 - Y20110 >= 0
#
# _C103: X01110 - Y01110 >= 0
#
# _C104: X11110 - Y11110 >= 0
#
# _C105: X21110 - Y21110 >= 0
#
# _C106: X02110 - Y02110 >= 0
#
# _C107: X12110 - Y12110 >= 0
#
# _C108: X22110 - Y22110 >= 0
#
# _C109: X00210 - Y00210 >= 0
#
# _C110: X10210 - Y10210 >= 0
#
# _C111: X20210 - Y20210 >= 0
#
# _C112: X01210 - Y01210 >= 0
#
# _C113: X11210 - Y11210 >= 0
#
# _C114: X21210 - Y21210 >= 0
#
# _C115: X02210 - Y02210 >= 0
#
# _C116: X12210 - Y12210 >= 0
#
# _C117: X22210 - Y22210 >= 0
#
# _C118: X00020 - Y00020 >= 0
#
# _C119: X10020 - Y10020 >= 0
#
# _C120: X20020 - Y20020 >= 0
#
# _C121: X01020 - Y01020 >= 0
#
# _C122: X11020 - Y11020 >= 0
#
# _C123: X21020 - Y21020 >= 0
#
# _C124: X02020 - Y02020 >= 0
#
# _C125: X12020 - Y12020 >= 0
#
# _C126: X22020 - Y22020 >= 0
#
# _C127: X00120 - Y00120 >= 0
#
# _C128: X10120 - Y10120 >= 0
#
# _C129: X20120 - Y20120 >= 0
#
# _C130: X01120 - Y01120 >= 0
#
# _C131: X11120 - Y11120 >= 0
#
# _C132: X21120 - Y21120 >= 0
#
# _C133: X02120 - Y02120 >= 0
#
# _C134: X12120 - Y12120 >= 0
#
# _C135: X22120 - Y22120 >= 0
#
# _C136: X00220 - Y00220 >= 0
#
# _C137: X10220 - Y10220 >= 0
#
# _C138: X20220 - Y20220 >= 0
#
# _C139: X01220 - Y01220 >= 0
#
# _C140: X11220 - Y11220 >= 0
#
# _C141: X21220 - Y21220 >= 0
#
# _C142: X02220 - Y02220 >= 0
#
# _C143: X12220 - Y12220 >= 0
#
# _C144: X22220 - Y22220 >= 0
#
# _C145: X00001 - Y00001 >= 0
#
# _C146: X10001 - Y10001 >= 0
#
# _C147: X20001 - Y20001 >= 0
#
# _C148: X01001 - Y01001 >= 0
#
# _C149: X11001 - Y11001 >= 0
#
# _C150: X21001 - Y21001 >= 0
#
# _C151: X02001 - Y02001 >= 0
#
# _C152: X12001 - Y12001 >= 0
#
# _C153: X22001 - Y22001 >= 0
#
# _C154: X00101 - Y00101 >= 0
#
# _C155: X10101 - Y10101 >= 0
#
# _C156: X20101 - Y20101 >= 0
#
# _C157: X01101 - Y01101 >= 0
#
# _C158: X11101 - Y11101 >= 0
#
# _C159: X21101 - Y21101 >= 0
#
# _C160: X02101 - Y02101 >= 0
#
# _C161: X12101 - Y12101 >= 0
#
# _C162: X22101 - Y22101 >= 0
#
# _C163: X00201 - Y00201 >= 0
#
# _C164: X10201 - Y10201 >= 0
#
# _C165: X20201 - Y20201 >= 0
#
# _C166: X01201 - Y01201 >= 0
#
# _C167: X11201 - Y11201 >= 0
#
# _C168: X21201 - Y21201 >= 0
#
# _C169: X02201 - Y02201 >= 0
#
# _C170: X12201 - Y12201 >= 0
#
# _C171: X22201 - Y22201 >= 0
#
# _C172: X00011 - Y00011 >= 0
#
# _C173: X10011 - Y10011 >= 0
#
# _C174: X20011 - Y20011 >= 0
#
# _C175: X01011 - Y01011 >= 0
#
# _C176: X11011 - Y11011 >= 0
#
# _C177: X21011 - Y21011 >= 0
#
# _C178: X02011 - Y02011 >= 0
#
# _C179: X12011 - Y12011 >= 0
#
# _C180: X22011 - Y22011 >= 0
#
# _C181: X00111 - Y00111 >= 0
#
# _C182: X10111 - Y10111 >= 0
#
# _C183: X20111 - Y20111 >= 0
#
# _C184: X01111 - Y01111 >= 0
#
# _C185: X11111 - Y11111 >= 0
#
# _C186: X21111 - Y21111 >= 0
#
# _C187: X02111 - Y02111 >= 0
#
# _C188: X12111 - Y12111 >= 0
#
# _C189: X22111 - Y22111 >= 0
#
# _C190: X00211 - Y00211 >= 0
#
# _C191: X10211 - Y10211 >= 0
#
# _C192: X20211 - Y20211 >= 0
#
# _C193: X01211 - Y01211 >= 0
#
# _C194: X11211 - Y11211 >= 0
#
# _C195: X21211 - Y21211 >= 0
#
# _C196: X02211 - Y02211 >= 0
#
# _C197: X12211 - Y12211 >= 0
#
# _C198: X22211 - Y22211 >= 0
#
# _C199: X00021 - Y00021 >= 0
#
# _C200: X10021 - Y10021 >= 0
#
# _C201: X20021 - Y20021 >= 0
#
# _C202: X01021 - Y01021 >= 0
#
# _C203: X11021 - Y11021 >= 0
#
# _C204: X21021 - Y21021 >= 0
#
# _C205: X02021 - Y02021 >= 0
#
# _C206: X12021 - Y12021 >= 0
#
# _C207: X22021 - Y22021 >= 0
#
# _C208: X00121 - Y00121 >= 0
#
# _C209: X10121 - Y10121 >= 0
#
# _C210: X20121 - Y20121 >= 0
#
# _C211: X01121 - Y01121 >= 0
#
# _C212: X11121 - Y11121 >= 0
#
# _C213: X21121 - Y21121 >= 0
#
# _C214: X02121 - Y02121 >= 0
#
# _C215: X12121 - Y12121 >= 0
#
# _C216: X22121 - Y22121 >= 0
#
# _C217: X00221 - Y00221 >= 0
#
# _C218: X10221 - Y10221 >= 0
#
# _C219: X20221 - Y20221 >= 0
#
# _C220: X01221 - Y01221 >= 0
#
# _C221: X11221 - Y11221 >= 0
#
# _C222: X21221 - Y21221 >= 0
#
# _C223: X02221 - Y02221 >= 0
#
# _C224: X12221 - Y12221 >= 0
#
# _C225: X22221 - Y22221 >= 0
#
# _C226: X00000 <= 0
#
# _C227: X10000 <= 0
#
# _C228: X20000 - 8 Y20000 <= 0
#
# _C229: X01000 - 12 Y01000 <= 0
#
# _C230: X11000 - 10 Y11000 <= 0
#
# _C231: X21000 <= 0
#
# _C232: X02000 <= 0
#
# _C233: X12000 <= 0
#
# _C234: X22000 <= 0
#
# _C235: X00100 <= 0
#
# _C236: X10100 <= 0
#
# _C237: X20100 <= 0
#
# _C238: X01100 <= 0
#
# _C239: X11100 <= 0
#
# _C240: X21100 <= 0
#
# _C241: X02100 - 14 Y02100 <= 0
#
# _C242: X12100 - 14 Y12100 <= 0
#
# _C243: X22100 - 8 Y22100 <= 0
#
# _C244: X00200 - 14 Y00200 <= 0
#
# _C245: X10200 - 14 Y10200 <= 0
#
# _C246: X20200 <= 0
#
# _C247: X01200 <= 0
#
# _C248: X11200 <= 0
#
# _C249: X21200 - 6 Y21200 <= 0
#
# _C250: X02200 <= 0
#
# _C251: X12200 <= 0
#
# _C252: X22200 <= 0
#
# _C253: X00010 <= 0
#
# _C254: X10010 <= 0
#
# _C255: X20010 - 8 Y20010 <= 0
#
# _C256: X01010 - 12 Y01010 <= 0
#
# _C257: X11010 - 10 Y11010 <= 0
#
# _C258: X21010 <= 0
#
# _C259: X02010 <= 0
#
# _C260: X12010 <= 0
#
# _C261: X22010 <= 0
#
# _C262: X00110 <= 0
#
# _C263: X10110 <= 0
#
# _C264: X20110 <= 0
#
# _C265: X01110 <= 0
#
# _C266: X11110 <= 0
#
# _C267: X21110 <= 0
#
# _C268: X02110 - 14 Y02110 <= 0
#
# _C269: X12110 - 14 Y12110 <= 0
#
# _C270: X22110 - 8 Y22110 <= 0
#
# _C271: X00210 - 14 Y00210 <= 0
#
# _C272: X10210 - 14 Y10210 <= 0
#
# _C273: X20210 <= 0
#
# _C274: X01210 <= 0
#
# _C275: X11210 <= 0
#
# _C276: X21210 - 6 Y21210 <= 0
#
# _C277: X02210 <= 0
#
# _C278: X12210 <= 0
#
# _C279: X22210 <= 0
#
# _C280: X00020 <= 0
#
# _C281: X10020 <= 0
#
# _C282: X20020 - 8 Y20020 <= 0
#
# _C283: X01020 - 12 Y01020 <= 0
#
# _C284: X11020 - 10 Y11020 <= 0
#
# _C285: X21020 <= 0
#
# _C286: X02020 <= 0
#
# _C287: X12020 <= 0
#
# _C288: X22020 <= 0
#
# _C289: X00120 <= 0
#
# _C290: X10120 <= 0
#
# _C291: X20120 <= 0
#
# _C292: X01120 <= 0
#
# _C293: X11120 <= 0
#
# _C294: X21120 <= 0
#
# _C295: X02120 - 14 Y02120 <= 0
#
# _C296: X12120 - 14 Y12120 <= 0
#
# _C297: X22120 - 8 Y22120 <= 0
#
# _C298: X00220 - 14 Y00220 <= 0
#
# _C299: X10220 - 14 Y10220 <= 0
#
# _C300: X20220 <= 0
#
# _C301: X01220 <= 0
#
# _C302: X11220 <= 0
#
# _C303: X21220 - 6 Y21220 <= 0
#
# _C304: X02220 <= 0
#
# _C305: X12220 <= 0
#
# _C306: X22220 <= 0
#
# _C307: X00001 <= 0
#
# _C308: X10001 <= 0
#
# _C309: X20001 - 8 Y20001 <= 0
#
# _C310: X01001 - 12 Y01001 <= 0
#
# _C311: X11001 - 10 Y11001 <= 0
#
# _C312: X21001 <= 0
#
# _C313: X02001 <= 0
#
# _C314: X12001 <= 0
#
# _C315: X22001 <= 0
#
# _C316: X00101 <= 0
#
# _C317: X10101 <= 0
#
# _C318: X20101 <= 0
#
# _C319: X01101 <= 0
#
# _C320: X11101 <= 0
#
# _C321: X21101 <= 0
#
# _C322: X02101 - 14 Y02101 <= 0
#
# _C323: X12101 - 14 Y12101 <= 0
#
# _C324: X22101 - 8 Y22101 <= 0
#
# _C325: X00201 - 14 Y00201 <= 0
#
# _C326: X10201 - 14 Y10201 <= 0
#
# _C327: X20201 <= 0
#
# _C328: X01201 <= 0
#
# _C329: X11201 <= 0
#
# _C330: X21201 - 6 Y21201 <= 0
#
# _C331: X02201 <= 0
#
# _C332: X12201 <= 0
#
# _C333: X22201 <= 0
#
# _C334: X00011 <= 0
#
# _C335: X10011 <= 0
#
# _C336: X20011 - 8 Y20011 <= 0
#
# _C337: X01011 - 12 Y01011 <= 0
#
# _C338: X11011 - 10 Y11011 <= 0
#
# _C339: X21011 <= 0
#
# _C340: X02011 <= 0
#
# _C341: X12011 <= 0
#
# _C342: X22011 <= 0
#
# _C343: X00111 <= 0
#
# _C344: X10111 <= 0
#
# _C345: X20111 <= 0
#
# _C346: X01111 <= 0
#
# _C347: X11111 <= 0
#
# _C348: X21111 <= 0
#
# _C349: X02111 - 14 Y02111 <= 0
#
# _C350: X12111 - 14 Y12111 <= 0
#
# _C351: X22111 - 8 Y22111 <= 0
#
# _C352: X00211 - 14 Y00211 <= 0
#
# _C353: X10211 - 14 Y10211 <= 0
#
# _C354: X20211 <= 0
#
# _C355: X01211 <= 0
#
# _C356: X11211 <= 0
#
# _C357: X21211 - 6 Y21211 <= 0
#
# _C358: X02211 <= 0
#
# _C359: X12211 <= 0
#
# _C360: X22211 <= 0
#
# _C361: X00021 <= 0
#
# _C362: X10021 <= 0
#
# _C363: X20021 - 8 Y20021 <= 0
#
# _C364: X01021 - 12 Y01021 <= 0
#
# _C365: X11021 - 10 Y11021 <= 0
#
# _C366: X21021 <= 0
#
# _C367: X02021 <= 0
#
# _C368: X12021 <= 0
#
# _C369: X22021 <= 0
#
# _C370: X00121 <= 0
#
# _C371: X10121 <= 0
#
# _C372: X20121 <= 0
#
# _C373: X01121 <= 0
#
# _C374: X11121 <= 0
#
# _C375: X21121 <= 0
#
# _C376: X02121 - 14 Y02121 <= 0
#
# _C377: X12121 - 14 Y12121 <= 0
#
# _C378: X22121 - 8 Y22121 <= 0
#
# _C379: X00221 - 14 Y00221 <= 0
#
# _C380: X10221 - 14 Y10221 <= 0
#
# _C381: X20221 <= 0
#
# _C382: X01221 <= 0
#
# _C383: X11221 <= 0
#
# _C384: X21221 - 6 Y21221 <= 0
#
# _C385: X02221 <= 0
#
# _C386: X12221 <= 0
#
# _C387: X22221 <= 0
#
# _C388: - 3 0 <= 0
#
# _C389: - 3 1 <= 0
#
# _C390: - 3 2 <= 0
#
# _C391: - 3 0 + Y02010 + Y02110 + Y02210 <= 0
#
# _C392: - 3 1 + Y12010 + Y12110 + Y12210 <= 0
#
# _C393: - 3 2 + Y22010 + Y22110 + Y22210 <= 0
#
# _C394: - 3 0 + 2 Y02020 + 2 Y02120 + 2 Y02220 <= 0
#
# _C395: - 3 1 + 2 Y12020 + 2 Y12120 + 2 Y12220 <= 0
#
# _C396: - 3 2 + 2 Y22020 + 2 Y22120 + 2 Y22220 <= 0
#
# _C397: - 3 0 <= 0
#
# _C398: - 3 1 <= 0
#
# _C399: - 3 2 <= 0
#
# _C400: - 3 0 + Y02011 + Y02111 + Y02211 <= 0
#
# _C401: - 3 1 + Y12011 + Y12111 + Y12211 <= 0
#
# _C402: - 3 2 + Y22011 + Y22111 + Y22211 <= 0
#
# _C403: - 3 0 + 2 Y02021 + 2 Y02121 + 2 Y02221 <= 0
#
# _C404: - 3 1 + 2 Y12021 + 2 Y12121 + 2 Y12221 <= 0
#
# _C405: - 3 2 + 2 Y22021 + 2 Y22121 + 2 Y22221 <= 0
#
# _C406:0 >= 0
#
# _C407:0 >= 0
#
# _C408: - 8 Y21000 - 8 Y21100 - 8 Y21200 >= 0
#
# _C409: - 12 Y02000 - 12 Y02100 - 12 Y02200 >= 0
#
# _C410: - 10 Y12000 - 10 Y12100 - 10 Y12200 >= 0
#
# _C411:0 >= 0
#
# _C412:0 >= 0
#
# _C413:0 >= 0
#
# _C414:0 >= 0
#
# _C415:0 >= 0
#
# _C416:0 >= 0
#
# _C417:0 >= 0
#
# _C418: - 14 Y01000 - 14 Y01100 - 14 Y01200 >= 0
#
# _C419: - 14 Y11000 - 14 Y11100 - 14 Y11200 >= 0
#
# _C420:0 >= 0
#
# _C421:0 >= 0
#
# _C422:0 >= 0
#
# _C423: - 6 Y22000 - 6 Y22100 - 6 Y22200 >= 0
#
# _C424:0 >= 0
#
# _C425:0 >= 0
#
# _C426: - 8 Y21010 - 8 Y21110 - 8 Y21210 >= 0
#
# _C427: - 12 Y02010 - 12 Y02110 - 12 Y02210 >= 0
#
# _C428: - 10 Y12010 - 10 Y12110 - 10 Y12210 >= 0
#
# _C429:0 >= 0
#
# _C430:0 >= 0
#
# _C431:0 >= 0
#
# _C432:0 >= 0
#
# _C433:0 >= 0
#
# _C434:0 >= 0
#
# _C435:0 >= 0
#
# _C436: - 14 Y01010 - 14 Y01110 - 14 Y01210 >= 0
#
# _C437: - 14 Y11010 - 14 Y11110 - 14 Y11210 >= 0
#
# _C438:0 >= 0
#
# _C439:0 >= 0
#
# _C440:0 >= 0
#
# _C441: - 6 Y22010 - 6 Y22110 - 6 Y22210 >= 0
#
# _C442: X00000 + X00001 >= 0
#
# _C443: X10000 + X10001 >= 0
#
# _C444: X20000 + X20001 - 8 Y21020 - 8 Y21120 - 8 Y21220 >= 0
#
# _C445: X01000 + X01001 - 12 Y02020 - 12 Y02120 - 12 Y02220 >= 0
#
# _C446: X11000 + X11001 - 10 Y12020 - 10 Y12120 - 10 Y12220 >= 0
#
# _C447: X21000 + X21001 >= 0
#
# _C448: X00100 + X00101 >= 0
#
# _C449: X10100 + X10101 >= 0
#
# _C450: X20100 + X20101 >= 0
#
# _C451: X01100 + X01101 >= 0
#
# _C452: X11100 + X11101 >= 0
#
# _C453: X21100 + X21101 >= 0
#
# _C454: X00200 + X00201 - 14 Y01020 - 14 Y01120 - 14 Y01220 >= 0
#
# _C455: X10200 + X10201 - 14 Y11020 - 14 Y11120 - 14 Y11220 >= 0
#
# _C456: X20200 + X20201 >= 0
#
# _C457: X01200 + X01201 >= 0
#
# _C458: X11200 + X11201 >= 0
#
# _C459: X21200 + X21201 - 6 Y22020 - 6 Y22120 - 6 Y22220 >= 0
#
# _C460:0 >= 0
#
# _C461:0 >= 0
#
# _C462: - 8 Y21001 - 8 Y21101 - 8 Y21201 >= 0
#
# _C463: - 12 Y02001 - 12 Y02101 - 12 Y02201 >= 0
#
# _C464: - 10 Y12001 - 10 Y12101 - 10 Y12201 >= 0
#
# _C465:0 >= 0
#
# _C466:0 >= 0
#
# _C467:0 >= 0
#
# _C468:0 >= 0
#
# _C469:0 >= 0
#
# _C470:0 >= 0
#
# _C471:0 >= 0
#
# _C472: - 14 Y01001 - 14 Y01101 - 14 Y01201 >= 0
#
# _C473: - 14 Y11001 - 14 Y11101 - 14 Y11201 >= 0
#
# _C474:0 >= 0
#
# _C475:0 >= 0
#
# _C476:0 >= 0
#
# _C477: - 6 Y22001 - 6 Y22101 - 6 Y22201 >= 0
#
# _C478: X00000 + X00001 >= 0
#
# _C479: X10000 + X10001 >= 0
#
# _C480: X20000 + X20001 - 8 Y21011 - 8 Y21111 - 8 Y21211 >= 0
#
# _C481: X01000 + X01001 - 12 Y02011 - 12 Y02111 - 12 Y02211 >= 0
#
# _C482: X11000 + X11001 - 10 Y12011 - 10 Y12111 - 10 Y12211 >= 0
#
# _C483: X21000 + X21001 >= 0
#
# _C484: X00100 + X00101 >= 0
#
# _C485: X10100 + X10101 >= 0
#
# _C486: X20100 + X20101 >= 0
#
# _C487: X01100 + X01101 >= 0
#
# _C488: X11100 + X11101 >= 0
#
# _C489: X21100 + X21101 >= 0
#
# _C490: X00200 + X00201 - 14 Y01011 - 14 Y01111 - 14 Y01211 >= 0
#
# _C491: X10200 + X10201 - 14 Y11011 - 14 Y11111 - 14 Y11211 >= 0
#
# _C492: X20200 + X20201 >= 0
#
# _C493: X01200 + X01201 >= 0
#
# _C494: X11200 + X11201 >= 0
#
# _C495: X21200 + X21201 - 6 Y22011 - 6 Y22111 - 6 Y22211 >= 0
#
# _C496: X00000 + X00001 + X00010 + X00011 >= 0
#
# _C497: X10000 + X10001 + X10010 + X10011 >= 0
#
# _C498: X20000 + X20001 + X20010 + X20011 - 8 Y21021 - 8 Y21121 - 8 Y21221 >= 0
#
# _C499: X01000 + X01001 + X01010 + X01011 - 12 Y02021 - 12 Y02121 - 12 Y02221
#  >= 0
#
# _C500: X11000 + X11001 + X11010 + X11011 - 10 Y12021 - 10 Y12121 - 10 Y12221
#  >= 0
#
# _C501: X21000 + X21001 + X21010 + X21011 >= 0
#
# _C502: X00100 + X00101 + X00110 + X00111 >= 0
#
# _C503: X10100 + X10101 + X10110 + X10111 >= 0
#
# _C504: X20100 + X20101 + X20110 + X20111 >= 0
#
# _C505: X01100 + X01101 + X01110 + X01111 >= 0
#
# _C506: X11100 + X11101 + X11110 + X11111 >= 0
#
# _C507: X21100 + X21101 + X21110 + X21111 >= 0
#
# _C508: X00200 + X00201 + X00210 + X00211 - 14 Y01021 - 14 Y01121 - 14 Y01221
#  >= 0
#
# _C509: X10200 + X10201 + X10210 + X10211 - 14 Y11021 - 14 Y11121 - 14 Y11221
#  >= 0
#
# _C510: X20200 + X20201 + X20210 + X20211 >= 0
#
# _C511: X01200 + X01201 + X01210 + X01211 >= 0
#
# _C512: X11200 + X11201 + X11210 + X11211 >= 0
#
# _C513: X21200 + X21201 + X21210 + X21211 - 6 Y22021 - 6 Y22121 - 6 Y22221 >= 0
#
# VARIABLES
# 0 <= 0 <= 1 Integer
# 0 <= 1 <= 1 Integer
# 0 <= 2 <= 1 Integer
# X00000 Continuous
# X00001 Continuous
# X00010 Continuous
# X00011 Continuous
# X00020 Continuous
# X00021 Continuous
# X00100 Continuous
# X00101 Continuous
# X00110 Continuous
# X00111 Continuous
# X00120 Continuous
# X00121 Continuous
# X00200 Continuous
# X00201 Continuous
# X00210 Continuous
# X00211 Continuous
# X00220 Continuous
# X00221 Continuous
# X01000 Continuous
# X01001 Continuous
# X01010 Continuous
# X01011 Continuous
# X01020 Continuous
# X01021 Continuous
# X01100 Continuous
# X01101 Continuous
# X01110 Continuous
# X01111 Continuous
# X01120 Continuous
# X01121 Continuous
# X01200 Continuous
# X01201 Continuous
# X01210 Continuous
# X01211 Continuous
# X01220 Continuous
# X01221 Continuous
# X02000 Continuous
# X02001 Continuous
# X02010 Continuous
# X02011 Continuous
# X02020 Continuous
# X02021 Continuous
# X02100 Continuous
# X02101 Continuous
# X02110 Continuous
# X02111 Continuous
# X02120 Continuous
# X02121 Continuous
# X02200 Continuous
# X02201 Continuous
# X02210 Continuous
# X02211 Continuous
# X02220 Continuous
# X02221 Continuous
# X10000 Continuous
# X10001 Continuous
# X10010 Continuous
# X10011 Continuous
# X10020 Continuous
# X10021 Continuous
# X10100 Continuous
# X10101 Continuous
# X10110 Continuous
# X10111 Continuous
# X10120 Continuous
# X10121 Continuous
# X10200 Continuous
# X10201 Continuous
# X10210 Continuous
# X10211 Continuous
# X10220 Continuous
# X10221 Continuous
# X11000 Continuous
# X11001 Continuous
# X11010 Continuous
# X11011 Continuous
# X11020 Continuous
# X11021 Continuous
# X11100 Continuous
# X11101 Continuous
# X11110 Continuous
# X11111 Continuous
# X11120 Continuous
# X11121 Continuous
# X11200 Continuous
# X11201 Continuous
# X11210 Continuous
# X11211 Continuous
# X11220 Continuous
# X11221 Continuous
# X12000 Continuous
# X12001 Continuous
# X12010 Continuous
# X12011 Continuous
# X12020 Continuous
# X12021 Continuous
# X12100 Continuous
# X12101 Continuous
# X12110 Continuous
# X12111 Continuous
# X12120 Continuous
# X12121 Continuous
# X12200 Continuous
# X12201 Continuous
# X12210 Continuous
# X12211 Continuous
# X12220 Continuous
# X12221 Continuous
# X20000 Continuous
# X20001 Continuous
# X20010 Continuous
# X20011 Continuous
# X20020 Continuous
# X20021 Continuous
# X20100 Continuous
# X20101 Continuous
# X20110 Continuous
# X20111 Continuous
# X20120 Continuous
# X20121 Continuous
# X20200 Continuous
# X20201 Continuous
# X20210 Continuous
# X20211 Continuous
# X20220 Continuous
# X20221 Continuous
# X21000 Continuous
# X21001 Continuous
# X21010 Continuous
# X21011 Continuous
# X21020 Continuous
# X21021 Continuous
# X21100 Continuous
# X21101 Continuous
# X21110 Continuous
# X21111 Continuous
# X21120 Continuous
# X21121 Continuous
# X21200 Continuous
# X21201 Continuous
# X21210 Continuous
# X21211 Continuous
# X21220 Continuous
# X21221 Continuous
# X22000 Continuous
# X22001 Continuous
# X22010 Continuous
# X22011 Continuous
# X22020 Continuous
# X22021 Continuous
# X22100 Continuous
# X22101 Continuous
# X22110 Continuous
# X22111 Continuous
# X22120 Continuous
# X22121 Continuous
# X22200 Continuous
# X22201 Continuous
# X22210 Continuous
# X22211 Continuous
# X22220 Continuous
# X22221 Continuous
# 0 <= Y00000 <= 1 Integer
# 0 <= Y00001 <= 1 Integer
# 0 <= Y00010 <= 1 Integer
# 0 <= Y00011 <= 1 Integer
# 0 <= Y00020 <= 1 Integer
# 0 <= Y00021 <= 1 Integer
# 0 <= Y00100 <= 1 Integer
# 0 <= Y00101 <= 1 Integer
# 0 <= Y00110 <= 1 Integer
# 0 <= Y00111 <= 1 Integer
# 0 <= Y00120 <= 1 Integer
# 0 <= Y00121 <= 1 Integer
# 0 <= Y00200 <= 1 Integer
# 0 <= Y00201 <= 1 Integer
# 0 <= Y00210 <= 1 Integer
# 0 <= Y00211 <= 1 Integer
# 0 <= Y00220 <= 1 Integer
# 0 <= Y00221 <= 1 Integer
# 0 <= Y01000 <= 1 Integer
# 0 <= Y01001 <= 1 Integer
# 0 <= Y01010 <= 1 Integer
# 0 <= Y01011 <= 1 Integer
# 0 <= Y01020 <= 1 Integer
# 0 <= Y01021 <= 1 Integer
# 0 <= Y01100 <= 1 Integer
# 0 <= Y01101 <= 1 Integer
# 0 <= Y01110 <= 1 Integer
# 0 <= Y01111 <= 1 Integer
# 0 <= Y01120 <= 1 Integer
# 0 <= Y01121 <= 1 Integer
# 0 <= Y01200 <= 1 Integer
# 0 <= Y01201 <= 1 Integer
# 0 <= Y01210 <= 1 Integer
# 0 <= Y01211 <= 1 Integer
# 0 <= Y01220 <= 1 Integer
# 0 <= Y01221 <= 1 Integer
# 0 <= Y02000 <= 1 Integer
# 0 <= Y02001 <= 1 Integer
# 0 <= Y02010 <= 1 Integer
# 0 <= Y02011 <= 1 Integer
# 0 <= Y02020 <= 1 Integer
# 0 <= Y02021 <= 1 Integer
# 0 <= Y02100 <= 1 Integer
# 0 <= Y02101 <= 1 Integer
# 0 <= Y02110 <= 1 Integer
# 0 <= Y02111 <= 1 Integer
# 0 <= Y02120 <= 1 Integer
# 0 <= Y02121 <= 1 Integer
# 0 <= Y02200 <= 1 Integer
# 0 <= Y02201 <= 1 Integer
# 0 <= Y02210 <= 1 Integer
# 0 <= Y02211 <= 1 Integer
# 0 <= Y02220 <= 1 Integer
# 0 <= Y02221 <= 1 Integer
# 0 <= Y10000 <= 1 Integer
# 0 <= Y10001 <= 1 Integer
# 0 <= Y10010 <= 1 Integer
# 0 <= Y10011 <= 1 Integer
# 0 <= Y10020 <= 1 Integer
# 0 <= Y10021 <= 1 Integer
# 0 <= Y10100 <= 1 Integer
# 0 <= Y10101 <= 1 Integer
# 0 <= Y10110 <= 1 Integer
# 0 <= Y10111 <= 1 Integer
# 0 <= Y10120 <= 1 Integer
# 0 <= Y10121 <= 1 Integer
# 0 <= Y10200 <= 1 Integer
# 0 <= Y10201 <= 1 Integer
# 0 <= Y10210 <= 1 Integer
# 0 <= Y10211 <= 1 Integer
# 0 <= Y10220 <= 1 Integer
# 0 <= Y10221 <= 1 Integer
# 0 <= Y11000 <= 1 Integer
# 0 <= Y11001 <= 1 Integer
# 0 <= Y11010 <= 1 Integer
# 0 <= Y11011 <= 1 Integer
# 0 <= Y11020 <= 1 Integer
# 0 <= Y11021 <= 1 Integer
# 0 <= Y11100 <= 1 Integer
# 0 <= Y11101 <= 1 Integer
# 0 <= Y11110 <= 1 Integer
# 0 <= Y11111 <= 1 Integer
# 0 <= Y11120 <= 1 Integer
# 0 <= Y11121 <= 1 Integer
# 0 <= Y11200 <= 1 Integer
# 0 <= Y11201 <= 1 Integer
# 0 <= Y11210 <= 1 Integer
# 0 <= Y11211 <= 1 Integer
# 0 <= Y11220 <= 1 Integer
# 0 <= Y11221 <= 1 Integer
# 0 <= Y12000 <= 1 Integer
# 0 <= Y12001 <= 1 Integer
# 0 <= Y12010 <= 1 Integer
# 0 <= Y12011 <= 1 Integer
# 0 <= Y12020 <= 1 Integer
# 0 <= Y12021 <= 1 Integer
# 0 <= Y12100 <= 1 Integer
# 0 <= Y12101 <= 1 Integer
# 0 <= Y12110 <= 1 Integer
# 0 <= Y12111 <= 1 Integer
# 0 <= Y12120 <= 1 Integer
# 0 <= Y12121 <= 1 Integer
# 0 <= Y12200 <= 1 Integer
# 0 <= Y12201 <= 1 Integer
# 0 <= Y12210 <= 1 Integer
# 0 <= Y12211 <= 1 Integer
# 0 <= Y12220 <= 1 Integer
# 0 <= Y12221 <= 1 Integer
# 0 <= Y20000 <= 1 Integer
# 0 <= Y20001 <= 1 Integer
# 0 <= Y20010 <= 1 Integer
# 0 <= Y20011 <= 1 Integer
# 0 <= Y20020 <= 1 Integer
# 0 <= Y20021 <= 1 Integer
# 0 <= Y20100 <= 1 Integer
# 0 <= Y20101 <= 1 Integer
# 0 <= Y20110 <= 1 Integer
# 0 <= Y20111 <= 1 Integer
# 0 <= Y20120 <= 1 Integer
# 0 <= Y20121 <= 1 Integer
# 0 <= Y20200 <= 1 Integer
# 0 <= Y20201 <= 1 Integer
# 0 <= Y20210 <= 1 Integer
# 0 <= Y20211 <= 1 Integer
# 0 <= Y20220 <= 1 Integer
# 0 <= Y20221 <= 1 Integer
# 0 <= Y21000 <= 1 Integer
# 0 <= Y21001 <= 1 Integer
# 0 <= Y21010 <= 1 Integer
# 0 <= Y21011 <= 1 Integer
# 0 <= Y21020 <= 1 Integer
# 0 <= Y21021 <= 1 Integer
# 0 <= Y21100 <= 1 Integer
# 0 <= Y21101 <= 1 Integer
# 0 <= Y21110 <= 1 Integer
# 0 <= Y21111 <= 1 Integer
# 0 <= Y21120 <= 1 Integer
# 0 <= Y21121 <= 1 Integer
# 0 <= Y21200 <= 1 Integer
# 0 <= Y21201 <= 1 Integer
# 0 <= Y21210 <= 1 Integer
# 0 <= Y21211 <= 1 Integer
# 0 <= Y21220 <= 1 Integer
# 0 <= Y21221 <= 1 Integer
# 0 <= Y22000 <= 1 Integer
# 0 <= Y22001 <= 1 Integer
# 0 <= Y22010 <= 1 Integer
# 0 <= Y22011 <= 1 Integer
# 0 <= Y22020 <= 1 Integer
# 0 <= Y22021 <= 1 Integer
# 0 <= Y22100 <= 1 Integer
# 0 <= Y22101 <= 1 Integer
# 0 <= Y22110 <= 1 Integer
# 0 <= Y22111 <= 1 Integer
# 0 <= Y22120 <= 1 Integer
# 0 <= Y22121 <= 1 Integer
# 0 <= Y22200 <= 1 Integer
# 0 <= Y22201 <= 1 Integer
# 0 <= Y22210 <= 1 Integer
# 0 <= Y22211 <= 1 Integer
# 0 <= Y22220 <= 1 Integer
# 0 <= Y22221 <= 1 Integer

# %% [markdown]
# Solving the problem:

# %%
problem.solve()
print("State:", pulp.LpStatus[problem.status])
for v in problem.variables():
  print(v.name, "=", v.varValue)
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.7/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/bc4fba5812a44bd5b5e3a378d1b8665c-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/bc4fba5812a44bd5b5e3a378d1b8665c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 518 COLUMNS
# At line 2355 RHS
# At line 2869 BOUNDS
# At line 3035 ENDATA
# Problem MODEL has 513 rows, 327 columns and 1341 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1700 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 10 strengthened rows, 5 substitutions
# Cgl0004I processed model has 84 rows, 55 columns (28 integer (28 of which binary)) and 206 elements
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of -1700
# Cbc0038I Relaxing continuous gives -1700
# Cbc0038I Before mini branch and bound, 28 integers at bound fixed and 27 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I After 0.01 seconds - Feasibility pump exiting with objective of -1700 - took 0.00 seconds
# Cbc0012I Integer solution of -1700 found by feasibility pump after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0001I Search completed - best objective -1700, took 0 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -1700 to -1700
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                1700.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# State: Optimal
# 0 = 0.0
# 1 = 0.0
# 2 = 1.0
# X00000 = 0.0
# X00001 = 0.0
# X00010 = 0.0
# X00011 = 0.0
# X00020 = 0.0
# X00021 = 0.0
# X00100 = 0.0
# X00101 = 0.0
# X00110 = 0.0
# X00111 = 0.0
# X00120 = 0.0
# X00121 = 0.0
# X00200 = 0.0
# X00201 = 0.0
# X00210 = 0.0
# X00211 = 0.0
# X00220 = 0.0
# X00221 = 0.0
# X01000 = 0.0
# X01001 = 0.0
# X01010 = 0.0
# X01011 = 0.0
# X01020 = 0.0
# X01021 = 0.0
# X01100 = 0.0
# X01101 = 0.0
# X01110 = 0.0
# X01111 = 0.0
# X01120 = 0.0
# X01121 = 0.0
# X01200 = 0.0
# X01201 = 0.0
# X01210 = 0.0
# X01211 = 0.0
# X01220 = 0.0
# X01221 = 0.0
# X02000 = 0.0
# X02001 = 0.0
# X02010 = 0.0
# X02011 = 0.0
# X02020 = 0.0
# X02021 = 0.0
# X02100 = 0.0
# X02101 = 0.0
# X02110 = 0.0
# X02111 = 0.0
# X02120 = 0.0
# X02121 = 0.0
# X02200 = 0.0
# X02201 = 0.0
# X02210 = 0.0
# X02211 = 0.0
# X02220 = 0.0
# X02221 = 0.0
# X10000 = 0.0
# X10001 = 0.0
# X10010 = 0.0
# X10011 = 0.0
# X10020 = 0.0
# X10021 = 0.0
# X10100 = 0.0
# X10101 = 0.0
# X10110 = 0.0
# X10111 = 0.0
# X10120 = 0.0
# X10121 = 0.0
# X10200 = 0.0
# X10201 = 0.0
# X10210 = 0.0
# X10211 = 0.0
# X10220 = 0.0
# X10221 = 0.0
# X11000 = 0.0
# X11001 = 0.0
# X11010 = 0.0
# X11011 = 0.0
# X11020 = 0.0
# X11021 = 0.0
# X11100 = 0.0
# X11101 = 0.0
# X11110 = 0.0
# X11111 = 0.0
# X11120 = 0.0
# X11121 = 0.0
# X11200 = 0.0
# X11201 = 0.0
# X11210 = 0.0
# X11211 = 0.0
# X11220 = 0.0
# X11221 = 0.0
# X12000 = 0.0
# X12001 = 0.0
# X12010 = 0.0
# X12011 = 0.0
# X12020 = 0.0
# X12021 = 0.0
# X12100 = 0.0
# X12101 = 0.0
# X12110 = 0.0
# X12111 = 0.0
# X12120 = 0.0
# X12121 = 0.0
# X12200 = 0.0
# X12201 = 0.0
# X12210 = 0.0
# X12211 = 0.0
# X12220 = 0.0
# X12221 = 0.0
# X20000 = 8.0
# X20001 = 0.0
# X20010 = 0.0
# X20011 = 0.0
# X20020 = 0.0
# X20021 = 0.0
# X20100 = 0.0
# X20101 = 0.0
# X20110 = 0.0
# X20111 = 0.0
# X20120 = 0.0
# X20121 = 0.0
# X20200 = 0.0
# X20201 = 0.0
# X20210 = 0.0
# X20211 = 0.0
# X20220 = 0.0
# X20221 = 0.0
# X21000 = 0.0
# X21001 = 0.0
# X21010 = 0.0
# X21011 = 0.0
# X21020 = 0.0
# X21021 = 0.0
# X21100 = 0.0
# X21101 = 0.0
# X21110 = 0.0
# X21111 = 0.0
# X21120 = 0.0
# X21121 = 0.0
# X21200 = 0.0
# X21201 = 0.0
# X21210 = 0.0
# X21211 = 6.0
# X21220 = 0.0
# X21221 = 0.0
# X22000 = 0.0
# X22001 = 0.0
# X22010 = 0.0
# X22011 = 0.0
# X22020 = 0.0
# X22021 = 0.0
# X22100 = 0.0
# X22101 = 0.0
# X22110 = 0.0
# X22111 = 0.0
# X22120 = 0.0
# X22121 = 8.0
# X22200 = 0.0
# X22201 = 0.0
# X22210 = 0.0
# X22211 = 0.0
# X22220 = 0.0
# X22221 = 0.0
# Y00000 = 0.0
# Y00001 = 0.0
# Y00010 = 0.0
# Y00011 = 0.0
# Y00020 = 0.0
# Y00021 = 0.0
# Y00100 = 0.0
# Y00101 = 0.0
# Y00110 = 0.0
# Y00111 = 0.0
# Y00120 = 0.0
# Y00121 = 0.0
# Y00200 = 0.0
# Y00201 = 0.0
# Y00210 = 0.0
# Y00211 = 0.0
# Y00220 = 0.0
# Y00221 = 0.0
# Y01000 = 0.0
# Y01001 = 0.0
# Y01010 = 0.0
# Y01011 = 0.0
# Y01020 = 0.0
# Y01021 = 0.0
# Y01100 = 0.0
# Y01101 = 0.0
# Y01110 = 0.0
# Y01111 = 0.0
# Y01120 = 0.0
# Y01121 = 0.0
# Y01200 = 0.0
# Y01201 = 0.0
# Y01210 = 0.0
# Y01211 = 0.0
# Y01220 = 0.0
# Y01221 = 0.0
# Y02000 = 0.0
# Y02001 = 0.0
# Y02010 = 0.0
# Y02011 = 0.0
# Y02020 = 0.0
# Y02021 = 0.0
# Y02100 = 0.0
# Y02101 = 0.0
# Y02110 = 0.0
# Y02111 = 0.0
# Y02120 = 0.0
# Y02121 = 0.0
# Y02200 = 0.0
# Y02201 = 0.0
# Y02210 = 0.0
# Y02211 = 0.0
# Y02220 = 0.0
# Y02221 = 0.0
# Y10000 = 0.0
# Y10001 = 0.0
# Y10010 = 0.0
# Y10011 = 0.0
# Y10020 = 0.0
# Y10021 = 0.0
# Y10100 = 0.0
# Y10101 = 0.0
# Y10110 = 0.0
# Y10111 = 0.0
# Y10120 = 0.0
# Y10121 = 0.0
# Y10200 = 0.0
# Y10201 = 0.0
# Y10210 = 0.0
# Y10211 = 0.0
# Y10220 = 0.0
# Y10221 = 0.0
# Y11000 = 0.0
# Y11001 = 0.0
# Y11010 = 0.0
# Y11011 = 0.0
# Y11020 = 0.0
# Y11021 = 0.0
# Y11100 = 0.0
# Y11101 = 0.0
# Y11110 = 0.0
# Y11111 = 0.0
# Y11120 = 0.0
# Y11121 = 0.0
# Y11200 = 0.0
# Y11201 = 0.0
# Y11210 = 0.0
# Y11211 = 0.0
# Y11220 = 0.0
# Y11221 = 0.0
# Y12000 = 0.0
# Y12001 = 0.0
# Y12010 = 0.0
# Y12011 = 0.0
# Y12020 = 0.0
# Y12021 = 0.0
# Y12100 = 0.0
# Y12101 = 0.0
# Y12110 = 0.0
# Y12111 = 0.0
# Y12120 = 0.0
# Y12121 = 0.0
# Y12200 = 0.0
# Y12201 = 0.0
# Y12210 = 0.0
# Y12211 = 0.0
# Y12220 = 0.0
# Y12221 = 0.0
# Y20000 = 1.0
# Y20001 = 0.0
# Y20010 = 0.0
# Y20011 = 0.0
# Y20020 = 0.0
# Y20021 = 0.0
# Y20100 = 0.0
# Y20101 = 0.0
# Y20110 = 0.0
# Y20111 = 0.0
# Y20120 = 0.0
# Y20121 = 0.0
# Y20200 = 0.0
# Y20201 = 0.0
# Y20210 = 0.0
# Y20211 = 0.0
# Y20220 = 0.0
# Y20221 = 0.0
# Y21000 = 0.0
# Y21001 = 0.0
# Y21010 = 0.0
# Y21011 = 0.0
# Y21020 = 0.0
# Y21021 = 0.0
# Y21100 = 0.0
# Y21101 = 0.0
# Y21110 = 0.0
# Y21111 = 0.0
# Y21120 = 0.0
# Y21121 = 0.0
# Y21200 = 0.0
# Y21201 = 0.0
# Y21210 = 0.0
# Y21211 = 1.0
# Y21220 = 0.0
# Y21221 = 0.0
# Y22000 = 0.0
# Y22001 = 0.0
# Y22010 = 0.0
# Y22011 = 0.0
# Y22020 = 0.0
# Y22021 = 0.0
# Y22100 = 0.0
# Y22101 = 0.0
# Y22110 = 0.0
# Y22111 = 0.0
# Y22120 = 0.0
# Y22121 = 1.0
# Y22200 = 0.0
# Y22201 = 0.0
# Y22210 = 0.0
# Y22211 = 0.0
# Y22220 = 0.0
# Y22221 = 0.0

# %%
print("Maximal profit: %d USD" % pulp.value(problem.objective))
# Out:
# Maximal profit: 1700 USD
